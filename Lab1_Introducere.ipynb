# %% [markdown]
# <a href="https://colab.research.google.com/github/VladTeapa/Python/blob/master/Lab1_Introducere.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introducere in Google Colab si Python
# [Google colab](https://research.google.com/colaboratory/faq.html) este o platforma online specializata in utilzarea TensorFlow pentru rularea retelelor neuronale de tip DeepLearning (mai multe despre aceasta daca o sa continuati sa fiti prezenti 😉). Platforma permite executarea in cloud de cod scris in limbajul Python fara a fi necesare instalarea si configurarea de tool-uri locale (e.g. Pycharm). De asemenea, puteti salva si partaja tot ceea ce lucrati foarte usor folosind google drive sau github (mai multe despre utilizarea github in anul 4 - **stay tuned**).

# %% [markdown]
# ##Google colab
# Utilizarea acestei platforme este foarte simpla. Ceea ce vedeti in fata voastra sunt "celule". Acestea pot fi de doua feluri: text sau cod.
# ###Celulele de tip text
# Pe langa ceea ce scrie deja, daca de exemplu doriti sa notati ceva in plus, puteti insera celule de tip text. Pentru aceasta apasati butonul *+ Text* din stanga sus. Editarea textului se face in "limbajul" markdown. Acest lucru nu este prea important daca doriti sa va luati doar notite simple. Pentru a vedea de exemplu cum anume a fost scris ceea ce voi cititi chiar acum in "limbajul" markdown apasati dublu click pe aceasta celula. Daca doriti sa dezvolati mai multe in markdown aveti [aici](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet) un mic tutorial.
# ###Celulele de tip cod
# In cadrul laboratoarelor o sa aveti celule de cod deja scrise si scurte exercitii pe care le veti face in cadrul laboratorului. Pentru a rezolva aceste exercitii, va trebui sa inserati celule cod apasand *+ Code* din stanga sus. Pentru a executa o celula cod apasati iconita run din stanga celulei. Foarte simplu, nu? 😊
# Un avantaj major al acestei platforme este acela ca puteti executa fiecare celula pe rand, fara a fi necesara reexecutarea celulelor anterioare (cum s-ar fi intamplat local la fiecare run al programului).

# %% [markdown]
# ##Python - *Let the games begin*
# Pentru a printa mesajul "Hello world" pe ecran executati celula de mai jos.

# %%
print("Hello world")

# %% [markdown]
# In Python, nu trebuie sa declarati o variabila inainte de a o utiliza si nici nu trebuie sa ii specificati tipul, acesta fiind dedus din valoarea variabilei (weakly typed). Afisarea pe ecran a mai multor variabile sau constante se face folosind functia ***print*** ca in exemplul de mai jos.

# %%
#De exemplu
a = 7.5 #float
b = 6 #integer
print("Suma numerelor ", a , " si ", b, "este ", a+b) 
a = "I like " #string
b = "multimedia labs" #string
print('Concaternarea sirului ', a, ' si a sirului ', b, 'este sirul: ', a+b)

# %% [markdown]
# Asignarea valorilor pentru o variabila sau mai multe se poate face simultan.

# %%
a, b = "This is a string", 7
print(a, b)

# %% [markdown]
# Pentru a converti o variabila numerica (integer sau float) la formatul string folositi functia ***str()***.

# %%
integer = 675
integerAsString = str(integer)
print(integerAsString)

# %% [markdown]
# **TODO:**
# Scrieti o celula de cod in care sa concatenati folosind operatorul plus un intreg si un string. Afisati pe ecran rezultatul obtinut.

# %%
#Concat
string = "string"
integer = 3
print (string + str(integer))
# Out:
# string3

# %% [markdown]
# Pentru a converti un string numeric la o variabila de tip integer folositi functia ***int()***.

# %%
stringAsInteger = "789"
integer = int(stringAsInteger)
print(integer)

# %% [markdown]
# Pentru a citi de la tastura un string folositi functia ***input()***.

# %%
string = input("Introduceti un string si apasati enter\n")
print("Ati introdus: ", string)

# %% [markdown]
# **TODO:** Scrieti o celula de cod in care sa cititi doua numere (sub forma de stringuri) de la tastura si afisati suma lor.

# %%
#Citire numere ca string
string1 = input("Nr1 : ")
string2 = input("Nr2 : ")
print(int(string1) + int(string2))
# Out:
# Nr1 : 2
# Nr2 : 3
# 5

# %% [markdown]
# Pentru a crea o instructiune decizionala folositi cuvantul cheie ***if***. Instructiunile din if se aseaza una dupa cealalta fiind separate doar de enter. Nu este necesara folosirea acoladelor.

# %%
a = 7
b = 5
c = a + b
if c == 12:
  print("Prima instructiune din if")
  print("A doua instructiune din if")
print("Prima instructiune din afara if-ului")

# %% [markdown]
# In exemplu urmator se defineste o functie care primeste ca si argument doua numere si intoarce suma acestora. Pentru a defini o functie se foloseste cuvantul cheie ***def***. Ca si in cazul instructiunii if nu exista acolade, instructiunile din functie se aseaza dupa ":" separate prin enter.

# %%
def suma(a, b):
  c = a + b
  return c

# %% [markdown]
# Pentru a putea folosi aceasta functie in alte celule de cod, rulati celula precedenta.

# %%
print(suma(8, 10))

# %% [markdown]
# ***TODO:*** Scrieti o functie care primeste ca si argumente 3 numere si returneaza maximul dintre acestea.

# %%
def maxim(a, b, c):
  if(a>=b):
    if(a>=c):
      return a
    else:
      return c
  else:
    if(b>=c):
      return b
    else:
      return c
print(maxim(input("Primul: "),input("Al doilea: "),input("Al treilea: ")))
# Out:
# Primul: 2
# Al doilea: 3
# Al treilea: 1
# 3

# %% [markdown]
# In exemplu de mai jos se modeleaza o lista de elemente. Spre deosebire de C/C++ crearea si utilizarea listelor este mult mai simpla. Functia ***append()*** adauga elemente in lista. Pentru a accesa elemnte din lista folositi operatorul **[ ]**.

# %%
lista = []
lista.append(7)
lista.append('Acesta este un string')
lista.append(8.9)
print(lista[0])
print(lista[1])
print(lista[2])

# %% [markdown]
# Pentru parcurgerea unei liste se foloseste ***for***. O lista se poate parcurge direct pe elementele din aceasta sau folosind un index dupa cum arata exemplul de mai jos. Folosind ***range()*** se specifica intervalul ce va fi parcurs. Functia ***len()*** returneaza lungimea listei.

# %%
#parcurgea directa 
for element in lista:
  print(element)
#parcurgerea prin index
for i in range(len(lista)):
  print(lista[i])

# %% [markdown]
# In exemplu de mai sus, varibila *i* va itera prin intervaul determinat de range(len(lista)) adica print multimea: 0, 1 si 2 (deoarece lista are 3 elemente). La modul general, daca se doreste un control mai mare asupra intervalului parcurs, functiei range i se vor specifica 3 parametrii: start (de unde incepe intervalul), stop (unde se opreste), step (pasul cu care se intereaza). Acesta sintaxa este echivalenta cu sintaxa clasica a unui for in C: for(i=start; i<stop; i=i+step). Priviti exemplul de mai jos.

# %%
lista = []
for i in range(10): #deci 0, 1, 2,...,9
  lista.append(i)
#acum se intereaza din 2 in 2 de la 0 pana a 6
for i in range(0, 7, 2): #deci 0, 2, 4, 6
  print(lista[i])

# %% [markdown]
# ***TODO:*** Scrieti o functie care primeste ca si argumente doua liste: o lista de numere intregi si o lista de valori cuprinse intre 0 si 1. Functia returneaza media ponderata a numerelor din prima lista cu ponderile din cea de a doua lista. Exemplu: lista1={2, 3, 5}, lista2={0.2, 0.3, 0.5} rezultat: 2x0.2+3x0.3+5x0.5=3.8.

# %%
def mediaponderata(numere, pondere):
  suma=float(0.0)
  for i in range(len(numere)):
    suma+=numere[i]*pondere[i]
  return suma
x = input("Numarul de elemente ")
lista = [];
listaponderi = [];
for i in range(0,int(x)):
  lista.append(float(input("Numarul " + str(i) + " :")))
  listaponderi.append(float(input("Ponderea " + str(i) + " :")))
print ("Media ponderata este: " + str(mediaponderata(lista,listaponderi)))
# Out:
# Numarul de elemente 3
# Numarul 0 :2
# Ponderea 0 :0.2
# Numarul 1 :3
# Ponderea 1 :0.3
# Numarul 2 :1
# Ponderea 2 :0.1
# Media ponderata este: 1.4

# %% [markdown]
# ##**Matplotlib**
# Matplotlib este o librarie Python care permite afisarea de imagini, grafice 2D, suprafete in 3D etc. Pentru a utiliza libraria aceasta trebuie mai intai de toate importata. Mai jos se importa din matplotlib functiile aferente *pyplot*. *Pyplot* reprezinta un subset de functii care vor fi utilizate in continuare. Pentru a nu scrie de fiecare data *matplotlib.plyplot.numele_functiei*, cand s-a importat libraria a fost denumita simplu ***plt*** (intuitiv, aceasta reprezinta o prescurate a *matplotlib.pyplot*).

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Fie o lista de coordonate x={1,2,3,4} si o lista de coordonate y={7,8,9,10}. Se doreste afisarea punctelor de coordonate (x[i], y[i]).

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [7, 8, 9, 10]
#traseaza puntele
plt.scatter(x, y)
#titlul graficului
plt.title('Primul grafic in Python')
#denumire axe
plt.xlabel('Axa x')
plt.ylabel('Axa y')
plt.show()

# %% [markdown]
# Se observa ca axele sunt scalate automat. Axa x se desfasoara de la 1 la 4 iar axa y de la 7 la 10. Pentru setarea manuala a limitei unei axe se foloseste functia ***plt.axis***.

# %%
xmin = 1
xmax = 10
ymin = 1
ymax = 10
plt.axis([xmin, xmax, ymin, ymax])

plt.scatter(x, y)
plt.title('Al doilea grafic in Python')
plt.xlabel('Axa x')
plt.ylabel('Axa y')
plt.show()

# %% [markdown]
# **TODO:**Creati o celula de cod in care sa afisati graficul functiei $f(x) =x^2+2x+5$ pentru $x=1,3,5,7,....,101$.

# %%
import matplotlib.pyplot as plt

x = range(1,102,2)
y = []
for i in x:
  y.append(i**2 + 2*i + 5)
plt.scatter(x,y)
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# Pentru a uni punctele din graficul de mai sus, functia ***plt.scatter*** se inlocuieste cu functia ***plt.plot***.

# %%
x = [1, 2, 3, 4]
y = [11, 3, 22, 17]
#traseaza puntele
plt.plot(x, y)
#titlul graficului
plt.title('Primul grafic in Python')
#denumire axe
plt.xlabel('Axa x')
plt.ylabel('Axa y')
plt.show()

# %% [markdown]
# **TODO:** Trasafi graficul functiei de mai sus pentru $x=1,2,3,4,....,1000$. Graficul trebuie sa fie continuu.

# %%
import matplotlib.pyplot as plt

x = range(1,102,2)
y = []
for i in x:
  y.append(i**2 + 2*i + 5)
plt.plot(x,y)
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# Functia ***plt.plot*** permite afisarea mai multor grafice pe aceeasi figura in stiluri si culori diferite. In exemplu de mai jos se afiseaza un grafic rosu cu liniute (r--), un grafic albastru cu patratele (bs) si un grafic verde cu triunghiuri (g^).

# %%
t = np.arange(0, 10, 1)
plt.plot(t, t, 'r--', t, 2*t, 'bs', t, 5*t, 'g^')
plt.show()

# %% [markdown]
# Pentru a afisa un grafic interactiv al unei suprafete in 3D se foloseste functia ***go.Surface*** din libraria **plotly** ca in exemplu de mai jos. Aceasta se poate instala folosind comanda pip.

# %%
# !pip install plotly==4.4.1

# %%
# !pip install chart-studio

# %% [markdown]
# Folosind functia ***np.linspace(start, stop, num)*** se genereaza un numar de **num** numere din intervalul **start**, **stop** egal departate intre ele. In exemplul de mai jos se afiseaza suprafata $z=sin(xy)$.

# %%
import plotly.graph_objects as go
import numpy as np
x=np.linspace(-2,2, 100)
y=np.linspace(-2,2, 100)
X,Y=np.meshgrid(x,y)
Z=np.sin(X*Y) 

fig = go.Figure(data=[go.Surface(z=Z)])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="07d16b1f-41fa-406a-9de8-845f7b29445b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("07d16b1f-41fa-406a-9de8-845f7b29445b")) {
#                     Plotly.newPlot(
#                         '07d16b1f-41fa-406a-9de8-845f7b29445b',
# ...

# %% [markdown]
# Pentru a afisa in 3D o multime discreta de puncte se foloseste functia ***go.Scatter3d*** din aceeasi librarie. In exemplu de mai jos, am parametrizat sinusul generat anterior.

# %%
import plotly.graph_objects as go
import numpy as np

t = np.linspace(0, 10, 50)
#x, y, z = np.sin(t), np.sin(t**2), t
x, y, z = np.cos(t), np.sin(t), t
fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z,
                                   mode='markers')])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="818fb48c-f67a-4dae-8a23-c5f2566f022d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("818fb48c-f67a-4dae-8a23-c5f2566f022d")) {
#                     Plotly.newPlot(
#                         '818fb48c-f67a-4dae-8a23-c5f2566f022d',
# ...

# %% [markdown]
# **TODO:** Implementati un program python care sa permita vizualizarea datelor random. Generati puncte random in plan (2 coordonate random) iar mai apoi in spatiu (3 coordonate random). Folositi functiile de mai sus pentru a afisa ceea ce ati generat.

# %%
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import numpy as np
from random import randint
x,y,z = [],[],[] 
for _ in range(0,100):
  x.append(randint(0,10))
  y.append(randint(0,10))
  z.append(randint(0,10))
plt.scatter(x,y)
plt.show()
fig = go.Figure(data=[go.Scatter3d(x=x,y=y,z=z,marker_symbol='cross', marker_color=randint(0,100), marker_size=5, showlegend=False, mode="markers+text")])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="08737c69-be42-4970-9ac1-775937261b1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("08737c69-be42-4970-9ac1-775937261b1a")) {
#                     Plotly.newPlot(
#                         '08737c69-be42-4970-9ac1-775937261b1a',
# ...
